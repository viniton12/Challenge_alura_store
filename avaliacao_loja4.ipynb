# %%
# importações de bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

# %%
loja4 = pd.read_csv('loja_4.csv')

df = pd.DataFrame(loja4)

display(loja4)
# Out:
#                     Produto   Categoria do Produto    Preço      Frete  \
# 0               Lava louças       eletrodomesticos  1446.46  74.604083
# 1                  Cama box                 moveis   631.70  33.919251
# 2          Bola de basquete        esporte e lazer    31.54   0.000000
# 3       Modelagem preditiva                 livros    76.93   1.680730
# 4            Fone de ouvido            eletronicos   185.14   7.442587
# ...                     ...                    ...      ...        ...
# 2353         Mesa de jantar                 moveis   303.60  16.852799
# 2354  Cadeira de escritório                 moveis   456.02  24.812798
# 2355           Copo térmico        esporte e lazer    48.99   3.139675
# 2356        Jogo de panelas  utilidades domesticas   202.45  11.062979
# 2357         Corda de pular        esporte e lazer    14.89   1.732696
#
#      Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0        11/11/2022    Rafael Costa              SP                    4
# 1        03/01/2020    Thiago Silva              GO                    5
# 2        25/12/2022   Larissa Alves              MG                    5
# 3        23/11/2021  Lucas Oliveira              MG                    3
# 4        25/04/2022   Bianca Santos              SP                    4
# ...             ...             ...             ...                  ...
# 2353     12/02/2020  Camila Ribeiro              RJ                    5
# 2354     17/05/2022   Felipe Santos              PE                    5
# 2355     03/05/2022  Camila Ribeiro              SP                    5
# 2356     15/06/2020   Bianca Santos              PR                    5
# 2357     17/11/2021   Felipe Santos              SP                    5
#
#      Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0       cartao_credito                       3 -22.19 -48.79
# 1       cartao_credito                       2 -15.98 -49.86
# 2               boleto                       1 -18.10 -44.38
# 3               boleto                       1 -18.10 -44.38
# 4       cartao_credito                       7 -22.19 -48.79
# ...                ...                     ...    ...    ...
# 2353    cartao_credito                       1 -22.25 -42.66
# 2354    cartao_credito                       3  -8.38 -37.86
# 2355    cartao_credito                       1 -22.19 -48.79
# 2356    cartao_credito                       1 -24.89 -51.55
# 2357    cartao_credito                       1 -22.19 -48.79
#
# [2358 rows x 12 columns]

# %%
#calcúlo do faturamento total de cada loja

def faturamento(df): #  uam função que calcula o faturamento da loja recebendo o paramêtro preço
    soma = df['Preço'].sum() # utilizamos sum() para calcúlar uma lista inteira do DataFrame
    return soma # retorna a soma da coluna preço 

fatura_total = faturamento(df) #C
print(f'o faturamento total da loja 4 foi de R$ {fatura_total}')
print('===' * 30)


# quantidade de vendas por categorias
#display(df['Categoria do Produto'].value_counts())

# ver a categoria mais vendida valor
contagem = df["Categoria do Produto"].value_counts()
print(contagem)
print('===' * 50)
categoria_mais_vendida_valor = contagem.max() # mostra o valor da categoria mais vendida
categoria_menos_vendida_valor= contagem.min() #mostra o valor da categoria menos vendida

# Categoria mais e menos vendida
categoria_mais_vendida = contagem.idxmax() #mostra o nome da categoria mais vendida
categoria_menos_vendida = contagem.idxmin() #mostra o nome da categoria menos vendida

print('===' * 50)
print(f' A categoria mais vendida foi {categoria_mais_vendida} com {categoria_mais_vendida_valor} unidades vendidas.')
print(f'A categoria menos vendida foi {categoria_menos_vendida} com {categoria_menos_vendida_valor} unidades vendidas.')

print('===' * 50)

# análise de avaliação do cliente
ava = display(df['Avaliação da compra'].value_counts())#exibe todas as avaliações dos clientes

media_avaliacao_loja = df['Avaliação da compra'].sum()/len(df['Avaliação da compra']) #tira á media de avaliação

print(f'A média de avaliação da loja foi {media_avaliacao_loja:.2f}')
print('===' * 50)

# em percentual
display(df['Avaliação da compra'].value_counts(normalize=True))  # exibi o percentual de avaliação da loja 
print('===' * 50)


#custo médio do frete para a loja 
custo_medio_frete =df['Frete'].sum()/len(df['Frete'])
print(f'O custo médio do frente  é de R$ {custo_medio_frete:.2f}.')
print('===' * 50)
# Out:
# o faturamento total da loja 4 foi de R$ 1384497.58
# ==========================================================================================
# Categoria do Produto
# moveis                   480
# eletronicos              451
# brinquedos               338
# esporte e lazer          277
# eletrodomesticos         254
# utilidades domesticas    201
# livros                   187
# instrumentos musicais    170
# Name: count, dtype: int64
# ======================================================================================================================================================
# ======================================================================================================================================================
#  A categoria mais vendida foi moveis com 480 unidades vendidas.
# A categoria menos vendida foi instrumentos musicais com 170 unidades vendidas.
# ======================================================================================================================================================
# Avaliação da compra
# 5    1300
# 4     453
# 1     310
# 3     210
# 2      85
# Name: count, dtype: int64
# A média de avaliação da loja foi 4.00
# ======================================================================================================================================================
# Avaliação da compra
# 5    0.551315
# 4    0.192112
# 1    0.131467
# 3    0.089059
# 2    0.036047
# Name: proportion, dtype: float64
# ======================================================================================================================================================
# O custo médio do frente  é de R$ 31.28.
# ======================================================================================================================================================

# %%
#  GRÁFICO  de quantidade de vendas por categorias 

# plot
plt.figure(figsize=(50, 5))

#grafico de dispersão para categoria do produto e o número de vendas
plt.subplot(131)
plt.scatter(contagem.index, contagem.values, color='blue')
#difinindo legendas e plotando o gráfico
plt.xticks(rotation=30, fontsize=10) # Rotaing axis ticks and customizing their font size
for i, v in enumerate(contagem.values):
    plt.text(i, v + 5, str(v), ha='center', color='black') #Adicionar os valores no topo das barras
plt.title('Número de vendas por categoria', color= 'darkred', fontsize= 15)
plt.ylabel('Quantidade', color= 'red')
plt.xlabel('Categória', color= 'red')
plt.show()


#GRÁFICO DE BARRAS
plt.figure(figsize=(50, 5))
plt.subplot(132)
plt.bar(contagem.index, contagem.values, color= 'skyblue')
#difinindo legendas e plotando o gráfico
plt.xticks(rotation=30, fontsize=10) # Rotaing axis ticks and customizing their font size
for i, v in enumerate(contagem.values):
    plt.text(i, v + 5, str(v), ha='center', color='black') #Adicionar os valores no topo das barras
plt.title('Número de vendas por  categoria', color= 'darkred', fontsize= 15)
plt.ylabel('Quantidade', color= 'red')
plt.xlabel('Categória', color= 'red')
plt.show()

#GRÁFICO DE LINHAS
plt.figure(figsize=(50, 5))
plt.subplot(133)
plt.plot(contagem.index, contagem.values, color= 'black')
#difinindo legendas e plotando o gráfico
plt.xticks(rotation=30, fontsize=10) # Rotaing axis ticks and customizing their font size
for i, v in enumerate(contagem.values):
    plt.text(i, v + 5, str(v), ha='center', color='black') #Adicionar os valores no topo das barras
plt.title('Número de vendas por categoria', color= 'darkred', fontsize= 15)
plt.ylabel('Quantidade', color= 'red')
plt.xlabel('Categória', color= 'red')
plt.show()

# %%
#GRáfico de pizza para avaliação dos usuários 
# Contagem das avaliações
ava = df['Avaliação da compra'].value_counts()

# Criando o gráfico
fig, ax = plt.subplots(figsize=(7, 7))  # Tamanho ideal
explode = (0.1, 0, 0, 0, 0)  #separa a fatia e dá um destaque
ax.pie(ava.values, explode= explode,  labels=ava.index, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal') # para a pizza ficar redondinha
plt.title('Avaliação da loja',  color= 'darkred', fontsize= 15)

plt.show()

# %%
#número de vendas por produtos
produtos = df['Produto'].value_counts()
display(produtos)

import pandas as pd

# Supondo que você tenha o DataFrame 'df' com os dados carregados
df['Faturamento'] = df['Preço'] * df['Quantidade de parcelas']  # ou 'Quantidade', dependendo do seu caso

# Agrupar por categoria e somar os faturamentos
faturamento_por_categoria = df.groupby('Categoria do Produto')['Faturamento'].sum().reset_index()

# Exibir o resultado
print(faturamento_por_categoria)

# Agrupar por produto e somar os faturamentos
faturamento_por_produto = df.groupby('Produto')['Faturamento'].sum().reset_index()

# Exibir o resultado
print(faturamento_por_produto)

import matplotlib.pyplot as plt

# Gráfico de faturamento por categoria
plt.figure(figsize=(15, 5))
plt.bar(faturamento_por_categoria['Categoria do Produto'], faturamento_por_categoria['Faturamento'], color='c')
plt.xlabel('Categoria')
plt.ylabel('Faturamento')
plt.title('Faturamento por Categoria')
plt.xticks(rotation=90)
plt.show()

# Gráfico de faturamento por produto
plt.figure(figsize=(15, 5))
plt.bar(faturamento_por_produto['Produto'], faturamento_por_produto['Faturamento'], color='g')
plt.xlabel('Produto')
plt.ylabel('Faturamento')
plt.title('Faturamento por Produto')
plt.xticks(rotation=90)
plt.show()


#GRÁFICO DE BARRAS vendas por produtos
plt.figure(figsize=(15, 5))

plt.bar(produtos.index, produtos.values, color= 'skyblue')
#difinindo legendas e plotando o gráfico
plt.xticks(rotation=90, fontsize=10) # Rotaing axis ticks and customizing their font size
for i, v in enumerate(produtos.values):
    plt.text(i, v + 5, str(v), ha='center', color='black') #Adicionar os valores no topo das barras
plt.title('Número de vendas por produto', color= 'darkred', fontsize= 15)
plt.ylabel('Quantidade', color= 'red')
plt.xlabel('Produto', color= 'red')
plt.show()
# Out:
# Produto
# Cama box                       62
# Faqueiro                       59
# Dashboards com Power BI        56
# Cama king                      56
# Carrinho controle remoto       55
# Mesa de jantar                 55
# Cômoda                         55
# Smart TV                       54
# Blocos de montar               54
# Pandeiro                       52
# Impressora                     50
# Modelagem preditiva            50
# Assistente virtual             50
# Jogo de panelas                50
# Bola de basquete               50
# Copo térmico                   48
# Celular Plus X42               48
# Boneca bebê                    48
# Bateria                        48
# Bola de vôlei                  48
# Jogo de tabuleiro              48
# Micro-ondas                    48
# Fogão                          47
# Cubo mágico 8x8                47
# Sofá retrátil                  47
# Dinossauro Rex                 47
# Panela de pressão              46
# Jogo de copos                  46
# Tablet ABXY                    45
# Poltrona                       45
# Bicicleta                      45
# Mesa de centro                 44
# Fone de ouvido                 44
# Lava louças                    43
# Corda de pular                 43
# Iniciando em programação       43
# Mochila                        43
# Headset                        42
# Kit banquetas                  42
# TV Led UHD 4K                  40
# Secadora de roupas             40
# Cadeira de escritório          40
# Celular ABXY                   39
# Xadrez de madeira              39
# Smartwatch                     39
# Lavadora de roupas             38
# Geladeira                      38
# Ciência de dados com python    38
# Violão                         37
# Guarda roupas                  34
# Guitarra                       33
# Name: count, dtype: int64
#     Categoria do Produto  Faturamento
# 0             brinquedos     72849.77
# 1       eletrodomesticos   1172119.35
# 2            eletronicos   1615256.00
# 3        esporte e lazer    133411.27
# 4  instrumentos musicais    297117.55
# 5                 livros     39390.51
# 6                 moveis    742172.64
# 7  utilidades domesticas     59436.05
#                         Produto  Faturamento
# 0            Assistente virtual     34066.44
# 1                       Bateria    138524.37
# 2                     Bicicleta     89132.73
# 3              Blocos de montar      6822.68
# 4              Bola de basquete      8496.86
# 5                 Bola de vôlei      7022.76
# 6                   Boneca bebê      8516.38
# 7         Cadeira de escritório     63623.74
# 8                      Cama box    136364.12
# 9                     Cama king    147151.49
# 10     Carrinho controle remoto     15555.69
# 11                 Celular ABXY    181361.39
# 12             Celular Plus X42    404023.28
# 13  Ciência de dados com python      9758.50
# 14                 Copo térmico      9197.56
# 15               Corda de pular      2385.30
# 16              Cubo mágico 8x8      2915.29
# 17                       Cômoda     57654.55
# 18      Dashboards com Power BI      9263.38
# 19               Dinossauro Rex      2691.73
# 20                     Faqueiro     11072.35
# 21                        Fogão     96918.06
# 22               Fone de ouvido     20093.31
# 23                    Geladeira    356478.20
# 24                Guarda roupas     56874.60
# 25                     Guitarra    104220.25
# 26                      Headset     30560.98
# 27                   Impressora     44991.64
# 28     Iniciando em programação      7935.70
# 29                Jogo de copos      5141.07
# 30              Jogo de panelas     28925.87
# 31            Jogo de tabuleiro     32205.13
# 32                Kit banquetas     42029.68
# 33                  Lava louças    198222.16
# 34           Lavadora de roupas    242832.39
# 35               Mesa de centro     28660.63
# 36               Mesa de jantar     54703.95
# 37                  Micro-ondas    114369.59
# 38                      Mochila     17176.06
# 39          Modelagem preditiva     12432.93
# 40                     Pandeiro     13895.52
# 41            Panela de pressão     14296.76
# 42                     Poltrona     38824.03
# 43           Secadora de roupas    163298.95
# 44                     Smart TV    289426.95
# 45                   Smartwatch     21556.61
# 46                Sofá retrátil    116285.85
# 47                TV Led UHD 4K    420462.20
# 48                  Tablet ABXY    168713.20
# 49                       Violão     40477.41
# 50            Xadrez de madeira      4142.87
