# %%
# importações de bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

# %%
loja3 = pd.read_csv('loja_3.csv')

df = pd.DataFrame(loja3)

display(loja3)
# Out:
#                       Produto   Categoria do Produto    Preço      Frete  \
# 0          Secadora de roupas       eletrodomesticos  1713.50  88.823159
# 1                      Cômoda                 moveis   386.81  18.180908
# 2                      Violão  instrumentos musicais   404.62  23.197592
# 3               Bola de vôlei        esporte e lazer    78.40   4.463341
# 4               Guarda roupas                 moveis   694.76  34.578319
# ...                       ...                    ...      ...        ...
# 2354  Dashboards com Power BI                 livros    35.61   2.835973
# 2355  Dashboards com Power BI                 livros    42.38   2.943620
# 2356    Cadeira de escritório                 moveis   636.10  34.159188
# 2357           Mesa de centro                 moveis   164.15   6.324933
# 2358      Modelagem preditiva                 livros    84.56  12.580214
#
#      Data da Compra          Vendedor Local da compra  Avaliação da compra  \
# 0        17/12/2021    Camila Ribeiro              CE                    4
# 1        10/02/2021     Larissa Alves              RS                    3
# 2        22/01/2023    Lucas Oliveira              SP                    5
# 3        22/03/2022       Pedro Gomes              BA                    4
# 4        12/01/2022     Bianca Santos              SP                    1
# ...             ...               ...             ...                  ...
# 2354     21/10/2022   Bruno Rodrigues              SP                    5
# 2355     23/06/2022     Bianca Santos              SC                    5
# 2356     19/02/2023    Camila Ribeiro              DF                    5
# 2357     19/09/2021     Bianca Santos              SP                    4
# 2358     24/05/2022  Mariana Ferreira              RJ                    5
#
#      Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0       cartao_credito                       4  -5.20 -39.53
# 1       cartao_credito                       1 -30.17 -53.50
# 2       cartao_credito                       3 -22.19 -48.79
# 3       cartao_credito                       6 -13.29 -41.71
# 4       cartao_credito                       1 -22.19 -48.79
# ...                ...                     ...    ...    ...
# 2354    cartao_credito                       1 -22.19 -48.79
# 2355    cartao_credito                       1 -27.45 -50.95
# 2356    cartao_credito                       3 -15.83 -47.86
# 2357    cartao_credito                       8 -22.19 -48.79
# 2358    cartao_credito                      10 -22.25 -42.66
#
# [2359 rows x 12 columns]

# %%
#calcúlo do faturamento total de cada loja

def faturamento(df): #  uam função que calcula o faturamento da loja recebendo o paramêtro preço
    soma = df['Preço'].sum() # utilizamos sum() para calcúlar uma lista inteira do DataFrame
    return soma # retorna a soma da coluna preço 

fatura_total = faturamento(df) #C
print(f'o faturamento total da loja 3 foi de R$ {fatura_total}')
print('===' * 30)


# quantidade de vendas por categorias
#display(df['Categoria do Produto'].value_counts())

# ver a categoria mais vendida valor
contagem = df["Categoria do Produto"].value_counts()
print(contagem)
print('===' * 50)
categoria_mais_vendida_valor = contagem.max() # mostra o valor da categoria mais vendida
categoria_menos_vendida_valor= contagem.min() #mostra o valor da categoria menos vendida

# Categoria mais e menos vendida
categoria_mais_vendida = contagem.idxmax() #mostra o nome da categoria mais vendida
categoria_menos_vendida = contagem.idxmin() #mostra o nome da categoria menos vendida

print('===' * 50)
print(f' A categoria mais vendida foi {categoria_mais_vendida} com {categoria_mais_vendida_valor} unidades vendidas.')
print(f'A categoria menos vendida foi {categoria_menos_vendida} com {categoria_menos_vendida_valor} unidades vendidas.')

print('===' * 50)

# análise de avaliação do cliente
ava = display(df['Avaliação da compra'].value_counts())#exibe todas as avaliações dos clientes

media_avaliacao_loja = df['Avaliação da compra'].sum()/len(df['Avaliação da compra']) #tira á media de avaliação

print(f'A média de avaliação da loja foi {media_avaliacao_loja:.2f}')
print('===' * 50)

# em percentual
display(df['Avaliação da compra'].value_counts(normalize=True))  # exibi o percentual de avaliação da loja 
print('===' * 50)


#custo médio do frete para a loja 
custo_medio_frete =df['Frete'].sum()/len(df['Frete'])
print(f'O custo médio do frente  é de R$ {custo_medio_frete:.2f}.')
print('===' * 50)
# Out:
# o faturamento total da loja 3 foi de R$ 1464025.03
# ==========================================================================================
# Categoria do Produto
# moveis                   499
# eletronicos              451
# brinquedos               315
# eletrodomesticos         278
# esporte e lazer          277
# livros                   185
# instrumentos musicais    177
# utilidades domesticas    177
# Name: count, dtype: int64
# ======================================================================================================================================================
# ======================================================================================================================================================
#  A categoria mais vendida foi moveis com 499 unidades vendidas.
# A categoria menos vendida foi instrumentos musicais com 177 unidades vendidas.
# ======================================================================================================================================================
# Avaliação da compra
# 5    1356
# 4     434
# 1     297
# 3     193
# 2      79
# Name: count, dtype: int64
# A média de avaliação da loja foi 4.05
# ======================================================================================================================================================
# Avaliação da compra
# 5    0.574820
# 4    0.183976
# 1    0.125901
# 3    0.081814
# 2    0.033489
# Name: proportion, dtype: float64
# ======================================================================================================================================================
# O custo médio do frente  é de R$ 33.07.
# ======================================================================================================================================================

# %%
#  GRÁFICO  de quantidade de vendas por categorias 

# plot
plt.figure(figsize=(50, 5))

#grafico de dispersão para categoria do produto e o número de vendas
plt.subplot(131)
plt.scatter(contagem.index, contagem.values, color='blue')
#difinindo legendas e plotando o gráfico
plt.xticks(rotation=30, fontsize=10) # Rotaing axis ticks and customizing their font size
for i, v in enumerate(contagem.values):
    plt.text(i, v + 5, str(v), ha='center', color='black') #Adicionar os valores no topo das barras
plt.title('Número de vendas por categoria', color= 'darkred', fontsize= 15)
plt.ylabel('Quantidade', color= 'red')
plt.xlabel('Categória', color= 'red')
plt.show()


#GRÁFICO DE BARRAS
plt.figure(figsize=(50, 5))
plt.subplot(132)
plt.bar(contagem.index, contagem.values, color= 'skyblue')
#difinindo legendas e plotando o gráfico
plt.xticks(rotation=30, fontsize=10) # Rotaing axis ticks and customizing their font size
for i, v in enumerate(contagem.values):
    plt.text(i, v + 5, str(v), ha='center', color='black') #Adicionar os valores no topo das barras
plt.title('Número de vendas por categoria', color= 'darkred', fontsize= 15)
plt.ylabel('Quantidade', color= 'red')
plt.xlabel('Categória', color= 'red')
plt.show()

#GRÁFICO DE LINHAS
plt.figure(figsize=(50, 5))
plt.subplot(133)
plt.plot(contagem.index, contagem.values, color= 'black')
#difinindo legendas e plotando o gráfico
plt.xticks(rotation=30, fontsize=10) # Rotaing axis ticks and customizing their font size
for i, v in enumerate(contagem.values):
    plt.text(i, v + 5, str(v), ha='center', color='black') #Adicionar os valores no topo das barras
plt.title('Número de vendas por categoria', color= 'darkred', fontsize= 15)
plt.ylabel('Quantidade', color= 'red')
plt.xlabel('Categória', color= 'red')
plt.show()

# %%
#GRáfico de pizza para avaliação dos usuários 
# Contagem das avaliações
ava = df['Avaliação da compra'].value_counts()

# Criando o gráfico
fig, ax = plt.subplots(figsize=(7, 7))  # Tamanho ideal
explode = (0.1, 0, 0, 0, 0)  #separa a fatia e dá um destaque
ax.pie(ava.values, explode= explode,  labels=ava.index, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal') # para a pizza ficar redondinha
plt.title('Avaliação da loja',  color= 'darkred', fontsize= 15)

plt.show()

# %%
#número de vendas por produtos
produtos = df['Produto'].value_counts()
display(produtos)

import pandas as pd

# Supondo que você tenha o DataFrame 'df' com os dados carregados
df['Faturamento'] = df['Preço'] * df['Quantidade de parcelas']  # ou 'Quantidade', dependendo do seu caso

# Agrupar por categoria e somar os faturamentos
faturamento_por_categoria = df.groupby('Categoria do Produto')['Faturamento'].sum().reset_index()

# Exibir o resultado
print(faturamento_por_categoria)

# Agrupar por produto e somar os faturamentos
faturamento_por_produto = df.groupby('Produto')['Faturamento'].sum().reset_index()

# Exibir o resultado
print(faturamento_por_produto)

import matplotlib.pyplot as plt

# Gráfico de faturamento por categoria
plt.figure(figsize=(15, 5))
plt.bar(faturamento_por_categoria['Categoria do Produto'], faturamento_por_categoria['Faturamento'], color='c')
plt.xlabel('Categoria')
plt.ylabel('Faturamento')
plt.title('Faturamento por Categoria')
plt.xticks(rotation=90)
plt.show()

# Gráfico de faturamento por produto
plt.figure(figsize=(15, 5))
plt.bar(faturamento_por_produto['Produto'], faturamento_por_produto['Faturamento'], color='g')
plt.xlabel('Produto')
plt.ylabel('Faturamento')
plt.title('Faturamento por Produto')
plt.xticks(rotation=90)
plt.show()


#GRÁFICO DE BARRAS vendas por produtos
plt.figure(figsize=(15, 5))

plt.bar(produtos.index, produtos.values, color= 'skyblue')
#difinindo legendas e plotando o gráfico
plt.xticks(rotation=90, fontsize=10) # Rotaing axis ticks and customizing their font size
for i, v in enumerate(produtos.values):
    plt.text(i, v + 5, str(v), ha='center', color='black') #Adicionar os valores no topo das barras
plt.title('Número de vendas por produto', color= 'darkred', fontsize= 15)
plt.ylabel('Quantidade', color= 'red')
plt.xlabel('Produto', color= 'red')
plt.show()
# Out:
# Produto
# Kit banquetas                  57
# Mesa de jantar                 56
# Cama king                      56
# Jogo de panelas                55
# Cômoda                         55
# Smart TV                       54
# Fogão                          53
# Corda de pular                 53
# Modelagem preditiva            53
# Carrinho controle remoto       52
# Lava louças                    52
# Bicicleta                      52
# Jogo de tabuleiro              52
# Pandeiro                       51
# Impressora                     50
# Geladeira                      50
# Bola de basquete               50
# Guarda roupas                  49
# Bola de vôlei                  48
# Tablet ABXY                    48
# Poltrona                       47
# Violão                         47
# Panela de pressão              47
# Xadrez de madeira              47
# Ciência de dados com python    46
# Celular Plus X42               46
# Dinossauro Rex                 46
# Cadeira de escritório          46
# Smartwatch                     46
# Cama box                       46
# Iniciando em programação       46
# Secadora de roupas             45
# Sofá retrátil                  45
# Celular ABXY                   44
# Cubo mágico 8x8                44
# Fone de ouvido                 43
# TV Led UHD 4K                  42
# Mesa de centro                 42
# Lavadora de roupas             42
# Bateria                        41
# Dashboards com Power BI        40
# Faqueiro                       39
# Boneca bebê                    39
# Headset                        39
# Assistente virtual             39
# Copo térmico                   38
# Guitarra                       38
# Jogo de copos                  36
# Mochila                        36
# Micro-ondas                    36
# Blocos de montar               35
# Name: count, dtype: int64
#     Categoria do Produto  Faturamento
# 0             brinquedos     81591.72
# 1       eletrodomesticos   1441845.38
# 2            eletronicos   1468443.69
# 3        esporte e lazer    164527.29
# 4  instrumentos musicais    333781.40
# 5                 livros     35142.69
# 6                 moveis    740123.50
# 7  utilidades domesticas     59635.75
#                         Produto  Faturamento
# 0            Assistente virtual     39283.12
# 1                       Bateria    137469.05
# 2                     Bicicleta    118961.04
# 3              Blocos de montar      5683.59
# 4              Bola de basquete      8857.32
# 5                 Bola de vôlei      9212.43
# 6                   Boneca bebê      7017.95
# 7         Cadeira de escritório     65948.36
# 8                      Cama box     84688.66
# 9                     Cama king    145478.76
# 10     Carrinho controle remoto     11137.09
# 11                 Celular ABXY    157041.70
# 12             Celular Plus X42    368191.32
# 13  Ciência de dados com python      8825.51
# 14                 Copo térmico      7501.89
# 15               Corda de pular      3775.19
# 16              Cubo mágico 8x8      2332.79
# 17                       Cômoda     64594.42
# 18      Dashboards com Power BI      5470.87
# 19               Dinossauro Rex      3010.78
# 20                     Faqueiro      6772.22
# 21                        Fogão    188914.12
# 22               Fone de ouvido     12880.00
# 23                    Geladeira    466797.98
# 24                Guarda roupas     98128.13
# 25                     Guitarra    112743.67
# 26                      Headset     27398.37
# 27                   Impressora     49248.40
# 28     Iniciando em programação      8753.32
# 29                Jogo de copos      5404.27
# 30              Jogo de panelas     32874.94
# 31            Jogo de tabuleiro     46456.27
# 32                Kit banquetas     56608.46
# 33                  Lava louças    229344.86
# 34           Lavadora de roupas    255862.79
# 35               Mesa de centro     25542.91
# 36               Mesa de jantar     53162.66
# 37                  Micro-ondas     78905.80
# 38                      Mochila     16219.42
# 39          Modelagem preditiva     12092.99
# 40                     Pandeiro     15066.23
# 41            Panela de pressão     14584.32
# 42                     Poltrona     45050.80
# 43           Secadora de roupas    222019.83
# 44                     Smart TV    275612.39
# 45                   Smartwatch     23366.77
# 46                Sofá retrátil    100920.34
# 47                TV Led UHD 4K    289630.01
# 48                  Tablet ABXY    225791.61
# 49                       Violão     68502.45
# 50            Xadrez de madeira      5953.25
