# %%
# importações de bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

# %%
loja2 = pd.read_csv('loja_2.csv')

df = pd.DataFrame(loja2)

display(loja2)
# Out:
#                     Produto   Categoria do Produto    Preço       Frete  \
# 0     Cadeira de escritório                 moveis   378.20   20.421138
# 1                  Pandeiro  instrumentos musicais   102.37    3.035334
# 2                 Cama king                 moveis   591.13   31.759020
# 3                 Cama king                 moveis  1208.24   61.919584
# 4     Cadeira de escritório                 moveis   530.41   25.827176
# ...                     ...                    ...      ...         ...
# 2354        Jogo de panelas  utilidades domesticas   187.01   10.846135
# 2355     Lavadora de roupas       eletrodomesticos  1626.85   86.907994
# 2356            Micro-ondas       eletrodomesticos  1063.85   57.177917
# 2357       Celular Plus X42            eletronicos  2965.72  155.500107
# 2358              Bicicleta        esporte e lazer   734.62   36.700744
#
#      Data da Compra          Vendedor Local da compra  Avaliação da compra  \
# 0        04/08/2021      Thiago Silva              MG                    1
# 1        26/11/2020     Bianca Santos              RJ                    3
# 2        22/10/2021      Thiago Silva              SC                    5
# 3        04/05/2022     Larissa Alves              RS                    5
# 4        26/02/2022    Lucas Oliveira              SP                    4
# ...             ...               ...             ...                  ...
# 2354     04/12/2022   Bruno Rodrigues              BA                    5
# 2355     09/02/2020  Isabella Pereira              SP                    4
# 2356     27/09/2022     Bianca Santos              SP                    5
# 2357     21/04/2022        João Souza              RJ                    5
# 2358     03/09/2022     Larissa Alves              MG                    4
#
#      Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0               boleto                       1 -18.10 -44.38
# 1       cartao_credito                       4 -22.25 -42.66
# 2       cartao_credito                      10 -27.45 -50.95
# 3       cartao_credito                      10 -30.17 -53.50
# 4       cartao_credito                       3 -22.19 -48.79
# ...                ...                     ...    ...    ...
# 2354    cartao_credito                       2 -13.29 -41.71
# 2355    cartao_credito                       5 -22.19 -48.79
# 2356            boleto                       1 -22.19 -48.79
# 2357    cartao_credito                       2 -22.25 -42.66
# 2358    cartao_credito                       1 -18.10 -44.38
#
# [2359 rows x 12 columns]

# %%
#calcúlo do faturamento total de cada loja

def faturamento(df): #  uam função que calcula o faturamento da loja recebendo o paramêtro preço
    soma = df['Preço'].sum() # utilizamos sum() para calcúlar uma lista inteira do DataFrame
    return soma # retorna a soma da coluna preço 

fatura_total = faturamento(df) #C
print(f'o faturamento total da loja 2 foi de R$ {fatura_total}')
print('===' * 30)


# quantidade de vendas por categorias
#display(df['Categoria do Produto'].value_counts())

# ver a categoria mais vendida valor
contagem = df["Categoria do Produto"].value_counts()
print(contagem)
print('===' * 50)
categoria_mais_vendida_valor = contagem.max() # mostra o valor da categoria mais vendida
categoria_menos_vendida_valor= contagem.min() #mostra o valor da categoria menos vendida

# Categoria mais e menos vendida
categoria_mais_vendida = contagem.idxmax() #mostra o nome da categoria mais vendida
categoria_menos_vendida = contagem.idxmin() #mostra o nome da categoria menos vendida

print('===' * 50)
print(f' A categoria mais vendida foi {categoria_mais_vendida} com {categoria_mais_vendida_valor} unidades vendidas.')
print(f'A categoria menos vendida foi {categoria_menos_vendida} com {categoria_menos_vendida_valor} unidades vendidas.')

print('===' * 50)

# análise de avaliação do cliente
ava = display(df['Avaliação da compra'].value_counts())#exibe todas as avaliações dos clientes

media_avaliacao_loja = df['Avaliação da compra'].sum()/len(df['Avaliação da compra']) #tira á media de avaliação

print(f'A média de avaliação da loja foi {media_avaliacao_loja:.2f}')
print('===' * 50)

# em percentual
display(df['Avaliação da compra'].value_counts(normalize=True))  # exibi o percentual de avaliação da loja 
print('===' * 50)


#custo médio do frete para a loja 
custo_medio_frete =df['Frete'].sum()/len(df['Frete'])
print(f'O custo médio do frente  é de R$ {custo_medio_frete:.2f}.')
print('===' * 50)
# Out:
# o faturamento total da loja 2 foi de R$ 1488459.06
# ==========================================================================================
# Categoria do Produto
# moveis                   442
# eletronicos              422
# brinquedos               313
# eletrodomesticos         305
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# utilidades domesticas    181
# Name: count, dtype: int64
# ======================================================================================================================================================
# ======================================================================================================================================================
#  A categoria mais vendida foi moveis com 442 unidades vendidas.
# A categoria menos vendida foi utilidades domesticas com 181 unidades vendidas.
# ======================================================================================================================================================
# Avaliação da compra
# 5    1302
# 4     482
# 1     273
# 3     209
# 2      93
# Name: count, dtype: int64
# A média de avaliação da loja foi 4.04
# ======================================================================================================================================================
# Avaliação da compra
# 5    0.551929
# 4    0.204324
# 1    0.115727
# 3    0.088597
# 2    0.039423
# Name: proportion, dtype: float64
# ======================================================================================================================================================
# O custo médio do frente  é de R$ 33.62.
# ======================================================================================================================================================

# %%
#  GRÁFICO  de quantidade de vendas por categorias 

# plot
plt.figure(figsize=(50, 5))

#grafico de dispersão para categoria do produto e o número de vendas
plt.subplot(131)
plt.scatter(contagem.index, contagem.values, color='blue')
#difinindo legendas e plotando o gráfico
plt.xticks(rotation=30, fontsize=10) # Rotaing axis ticks and customizing their font size
for i, v in enumerate(contagem.values):
    plt.text(i, v + 5, str(v), ha='center', color='black') #Adicionar os valores no topo das barras
plt.title('Número de vendas por categoria', color= 'darkred', fontsize= 15)
plt.ylabel('Quantidade', color= 'red')
plt.xlabel('Categória', color= 'red')
plt.show()


#GRÁFICO DE BARRAS
plt.figure(figsize=(50, 5))
plt.subplot(132)
plt.bar(contagem.index, contagem.values, color= 'skyblue')
#difinindo legendas e plotando o gráfico
plt.xticks(rotation=30, fontsize=10) # Rotaing axis ticks and customizing their font size
for i, v in enumerate(contagem.values):
    plt.text(i, v + 5, str(v), ha='center', color='black') #Adicionar os valores no topo das barras
plt.title('Número de vendas por categoria', color= 'darkred', fontsize= 15)
plt.ylabel('Quantidade', color= 'red')
plt.xlabel('Categória', color= 'red')
plt.show()

#GRÁFICO DE LINHAS
plt.figure(figsize=(50, 5))
plt.subplot(133)
plt.plot(contagem.index, contagem.values, color= 'black')
#difinindo legendas e plotando o gráfico
plt.xticks(rotation=30, fontsize=10) # Rotaing axis ticks and customizing their font size
for i, v in enumerate(contagem.values):
    plt.text(i, v + 5, str(v), ha='center', color='black') #Adicionar os valores no topo das barras
plt.title('Número de vendas por categoria', color= 'darkred', fontsize= 15)
plt.ylabel('Quantidade', color= 'red')
plt.xlabel('Categória', color= 'red')
plt.show()

# %%
#GRáfico de pizza para avaliação dos usuários 
# Contagem das avaliações
ava = df['Avaliação da compra'].value_counts()

# Criando o gráfico
fig, ax = plt.subplots(figsize=(7, 7))  # Tamanho ideal
explode = (0.1, 0, 0, 0, 0)  #separa a fatia e dá um destaque
ax.pie(ava.values, explode= explode,  labels=ava.index, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal') # para a pizza ficar redondinha
plt.title('Avaliação da loja',  color= 'darkred', fontsize= 15)
plt.show()

# %%
#número de vendas por produtos
produtos = df['Produto'].value_counts()
display(produtos)

import pandas as pd

# Supondo que você tenha o DataFrame 'df' com os dados carregados
df['Faturamento'] = df['Preço'] * df['Quantidade de parcelas']  # ou 'Quantidade', dependendo do seu caso

# Agrupar por categoria e somar os faturamentos
faturamento_por_categoria = df.groupby('Categoria do Produto')['Faturamento'].sum().reset_index()

# Exibir o resultado
print(faturamento_por_categoria)

# Agrupar por produto e somar os faturamentos
faturamento_por_produto = df.groupby('Produto')['Faturamento'].sum().reset_index()

# Exibir o resultado
print(faturamento_por_produto)

import matplotlib.pyplot as plt

# Gráfico de faturamento por categoria
plt.figure(figsize=(15, 5))
plt.bar(faturamento_por_categoria['Categoria do Produto'], faturamento_por_categoria['Faturamento'], color='c')
plt.xlabel('Categoria')
plt.ylabel('Faturamento')
plt.title('Faturamento por Categoria')
plt.xticks(rotation=90)
plt.show()

# Gráfico de faturamento por produto
plt.figure(figsize=(15, 5))
plt.bar(faturamento_por_produto['Produto'], faturamento_por_produto['Faturamento'], color='g')
plt.xlabel('Produto')
plt.ylabel('Faturamento')
plt.title('Faturamento por Produto')
plt.xticks(rotation=90)
plt.show()

#GRÁFICO DE BARRAS vendas por produtos
plt.figure(figsize=(15, 5))

plt.bar(produtos.index, produtos.values, color= 'skyblue')
#difinindo legendas e plotando o gráfico
plt.xticks(rotation=90, fontsize=10) # Rotaing axis ticks and customizing their font size
for i, v in enumerate(produtos.values):
    plt.text(i, v + 5, str(v), ha='center', color='black') #Adicionar os valores no topo das barras
plt.title('Número de vendas por produto', color= 'darkred', fontsize= 15)
plt.ylabel('Quantidade', color= 'red')
plt.xlabel('Produto', color= 'red')
plt.show()
# Out:
# Produto
# Iniciando em programação       65
# Micro-ondas                    62
# Bateria                        61
# Violão                         58
# Pandeiro                       58
# Secadora de roupas             57
# Celular Plus X42               55
# Blocos de montar               54
# Guarda roupas                  54
# Jogo de panelas                52
# Corda de pular                 50
# Lavadora de roupas             49
# Cadeira de escritório          49
# Geladeira                      49
# Boneca bebê                    48
# Carrinho controle remoto       47
# Guitarra                       47
# Cama box                       47
# Copo térmico                   47
# Modelagem preditiva            46
# Bola de vôlei                  46
# Jogo de copos                  46
# Lava louças                    46
# Kit banquetas                  45
# Cama king                      45
# Bicicleta                      45
# Mochila                        45
# Cubo mágico 8x8                45
# Xadrez de madeira              45
# Mesa de centro                 45
# TV Led UHD 4K                  45
# Tablet ABXY                    44
# Smartwatch                     44
# Cômoda                         44
# Panela de pressão              44
# Headset                        44
# Sofá retrátil                  44
# Dashboards com Power BI        43
# Ciência de dados com python    43
# Bola de basquete               42
# Fogão                          42
# Dinossauro Rex                 42
# Celular ABXY                   41
# Smart TV                       40
# Faqueiro                       39
# Assistente virtual             38
# Fone de ouvido                 37
# Poltrona                       35
# Mesa de jantar                 34
# Impressora                     34
# Jogo de tabuleiro              32
# Name: count, dtype: int64
#     Categoria do Produto  Faturamento
# 0             brinquedos     62300.37
# 1       eletrodomesticos   1368304.66
# 2            eletronicos   1715519.72
# 3        esporte e lazer    108879.57
# 4  instrumentos musicais    392599.48
# 5                 livros     41887.42
# 6                 moveis    703108.03
# 7  utilidades domesticas     56984.93
#                         Produto  Faturamento
# 0            Assistente virtual     32838.02
# 1                       Bateria    161437.57
# 2                     Bicicleta     65995.89
# 3              Blocos de montar      6240.26
# 4              Bola de basquete      6168.72
# 5                 Bola de vôlei      7652.52
# 6                   Boneca bebê      7910.54
# 7         Cadeira de escritório     83533.35
# 8                      Cama box     85821.28
# 9                     Cama king    122271.50
# 10     Carrinho controle remoto     13102.64
# 11                 Celular ABXY    161342.16
# 12             Celular Plus X42    523368.87
# 13  Ciência de dados com python     11612.38
# 14                 Copo térmico      8401.93
# 15               Corda de pular      2932.58
# 16              Cubo mágico 8x8      2442.54
# 17                       Cômoda     42294.56
# 18      Dashboards com Power BI      5071.93
# 19               Dinossauro Rex      3042.72
# 20                     Faqueiro      6430.87
# 21                        Fogão    117422.09
# 22               Fone de ouvido     19398.58
# 23                    Geladeira    398208.51
# 24                Guarda roupas    111454.24
# 25                     Guitarra    138176.14
# 26                      Headset     22964.91
# 27                   Impressora     42068.97
# 28     Iniciando em programação     13846.60
# 29                Jogo de copos      4482.42
# 30              Jogo de panelas     32854.27
# 31            Jogo de tabuleiro     24564.00
# 32                Kit banquetas     53375.39
# 33                  Lava louças    226737.18
# 34           Lavadora de roupas    243950.79
# 35               Mesa de centro     23419.40
# 36               Mesa de jantar     31549.55
# 37                  Micro-ondas    143494.20
# 38                      Mochila     17727.93
# 39          Modelagem preditiva     11356.51
# 40                     Pandeiro     15812.46
# 41            Panela de pressão     13217.37
# 42                     Poltrona     32389.64
# 43           Secadora de roupas    238491.89
# 44                     Smart TV    244557.12
# 45                   Smartwatch     28147.40
# 46                Sofá retrátil    116999.12
# 47                TV Led UHD 4K    378774.15
# 48                  Tablet ABXY    262059.54
# 49                       Violão     77173.31
# 50            Xadrez de madeira      4997.67
